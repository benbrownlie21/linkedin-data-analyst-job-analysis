# %% [markdown]
# We aim to analyse the linkedin jobs dataset to understand:
#
# 1. The biggest emplpoyers in the data/analyst space
# 2. The most in demand experience level in data/analyst space, broken down by states in the US.
# 3. Most popular employers and job titles
# 4. Most popular skills across all job postings
# 5. Which skills are most indemand in which industry
# 5. Most popular benefits across all job postings

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

file = ('/content/drive/MyDrive/Hackathon/postings2.csv')
df = pd.read_csv(file)
df.head(5)
# Out:
#      job_id            company_name  \
# 0    921716   Corcoran Sawyer Smith
# 1   1829192                     NaN
# 2  10998357  The National Exemplar
# 3  23221523  Abrams Fensterman, LLP
# 4  35982263                     NaN
#
#                                                title  \
# 0                              Marketing Coordinator
# 1                  Mental Health Therapist/Counselor
# 2                        Assitant Restaurant Manager
# 3  Senior Elder Law / Trusts and Estates Associat...
# 4                                 Service Technician
#
#                                          description  max_salary pay_period  \
# 0  Job descriptionA leading real estate firm in N...        20.0     HOURLY
# 1  At Aspen Therapy and Wellness , we are committ...        50.0     HOURLY
# 2  The National Exemplar is accepting application...     65000.0     YEARLY
# 3  Senior Associate Attorney - Elder Law / Trusts...    175000.0     YEARLY
# 4  Looking for HVAC service tech with experience ...     80000.0     YEARLY
#
#             location  company_id  views  med_salary  ...  closed_time  \
# 0      Princeton, NJ   2774458.0   20.0         NaN  ...          NaN
# 1   Fort Collins, CO         NaN    1.0         NaN  ...          NaN
# 2     Cincinnati, OH  64896719.0    8.0         NaN  ...          NaN
# 3  New Hyde Park, NY    766262.0   16.0         NaN  ...          NaN
# 4     Burlington, IA         NaN    3.0         NaN  ...          NaN
#
#   formatted_experience_level  \
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
#
#                                          skills_desc   listed_time  \
# 0  Requirements: \n\nWe are seeking a College or ...  1.713398e+12
# 1                                                NaN  1.712858e+12
# 2  We are currently accepting resumes for FOH - A...  1.713278e+12
# 3  This position requires a baseline understandin...  1.712896e+12
# 4                                                NaN  1.713452e+12
#
#    posting_domain sponsored  work_type currency  compensation_type  Experience
# 0             NaN         0  FULL_TIME      USD        BASE_SALARY         Mid
# 1             NaN         0  FULL_TIME      USD        BASE_SALARY         Mid
# 2             NaN         0  FULL_TIME      USD        BASE_SALARY  Management
# 3             NaN         0  FULL_TIME      USD        BASE_SALARY      Senior
# 4             NaN         0  FULL_TIME      USD        BASE_SALARY         Mid
#
# [5 rows x 29 columns]

# %% [markdown]
# Creating dataframe of columns we want to work with from the main dataframe. We realised that quite a few of the fields that we wanted to work with,
# like salary, were missing too many fields to be useful. We then created a another filtered dataframe to only include jobs that were either data related or analytics related.

# %%
postings_df = df[['job_id', 'company_name', 'title', 'description', 'location', 'formatted_experience_level', 'Experience', 'work_type', 'compensation_type', 'listed_time', 'expiry']]

# %%
pattern = '|'.join(['Business Analyst', 'Data Scientist', 'Business Intelligence Analyst', 'Data Engineer', 'Quantitative Analyst', 'Financial Analyst', 'Marketing Analyst', 'Financial Analyst', 'Marketing Analyst', 'Insights Analyst', 'Research Analyst', 'Data Consultant', 'Reporting Analyst', 'Analytics Consultant', 'Decision Support Analyst', 'Data Specialist', 'Analyst'])

filter_job = postings_df['title'].str.contains(pattern, case=False, na=False)

filtered_postings_df = postings_df[filter_job]
filtered_postings_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5598 entries, 63 to 123771
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   job_id                      5598 non-null   int64
#  1   company_name                5555 non-null   object
#  2   title                       5598 non-null   object
#  3   description                 5598 non-null   object
#  4   location                    5598 non-null   object
#  5   formatted_experience_level  4273 non-null   object
#  6   Experience                  5598 non-null   object
#  7   work_type                   5598 non-null   object
#  8   compensation_type           1913 non-null   object
#  9   listed_time                 5598 non-null   float64
#  10  expiry                      5598 non-null   float64
# dtypes: float64(2), int64(1), object(8)
# memory usage: 524.8+ KB

# %%
filtered_postings_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Checking for any NA fields. Compensation type was not useful to us but formatted_experience level was.
# We went through a few iterations of trying to populate the formatted_experience column and what worked finally is a python script
# to extract the experience level from the job title. So,for example, if the job title is Sr data analyst, the experience level became Senior.
# After that script was run, we had an experience column and could drop the formatted_expeience_level column.

# %%
filtered_postings_df.isna().sum()
# Out:
# job_id                           0
# company_name                    43
# title                            0
# description                      0
# location                         0
# formatted_experience_level    1325
# Experience                       0
# work_type                        0
# compensation_type             3685
# listed_time                      0
# expiry                           0
# dtype: int64

# %%
filtered_postings_df=filtered_postings_df.drop(['formatted_experience_level'], axis=1)
filtered_postings_df['company_name'].dropna(inplace=True)
#filtered_postings_df.head(5)

# %%
n = len(pd.unique(filtered_postings_df['title']))
print(n)
# Out:
# 3488

# %% [markdown]
# We needed to clean some of the columns, like time and location, into more usable formats.
# After splitting location into city and state, there were many fields that didn't follow any standard, for example the job would be for the Texas Metro area instead of just saying Texas. We made a keyword dictionary to remap the irregular entries to a state abbreviation, so Texas becomes TX.

# %%
#Converting the time column from epoch to standard time
filtered_postings_df['listed_time'] = pd.to_datetime(filtered_postings_df['listed_time']/1000, unit='s')
filtered_postings_df['expiry'] = pd.to_datetime(filtered_postings_df['expiry']/1000, unit='s')
# filtered_postings_df.head(5)

# %%
filtered_postings_df['expiry_month'] = filtered_postings_df['expiry'].dt.month

#filtered_postings_df.head(5)

# %%
expiry_month = filtered_postings_df.groupby(['expiry_month']).size()

# %%
#Splitting up the Location column into city and state columns so that we could analyse jobs based on locations.
filtered_postings_df['City']= df['location'].str.split(',', expand=True)[0]
filtered_postings_df['State']= df['location'].str.split(',', expand=True)[1]
filtered_postings_df.head(5)
# Out:
#          job_id             company_name                             title  \
# 63   1880409118  Kona Medical Consulting  Board Certified Behavior Analyst
# 69   2147609785          The Job Network                      FP&A Analyst
# 179  3582587683    McNaughton Bros. Inc.                  Accounts Analyst
# 283  3742692445          ZenithMinds Inc       Sr Data Engineer with Kafka
# 301  3763494664             HAPPI Health                 Help Desk Analyst
#
#                                            description  \
# 63   JOB OVERVIEW:\nThe BCBA will provide support t...
# 69   Integrity is one of the nation’s leading indep...
# 179  Company DescriptionMcNaughton Bros. Inc. is a ...
# 283  Data Engineer with Kafka (W2 Only)💯% Remote\nM...
# 301  Job DescriptionAssures the operation of the El...
#
#                                 location Experience  work_type  \
# 63                         McDonough, GA        Mid  FULL_TIME
# 69                            Dallas, TX        Mid  FULL_TIME
# 179                          Indiana, PA        Mid  FULL_TIME
# 283                           Austin, TX     Senior  FULL_TIME
# 301  Huntsville-Decatur-Albertville Area        Mid  FULL_TIME
#
#     compensation_type         listed_time              expiry  expiry_month  \
# 63                NaN 2024-04-19 06:42:23 2024-05-19 06:42:23             5
# 69                NaN 2024-04-12 06:46:24 2024-05-12 06:46:24             5
# 179       BASE_SALARY 2024-04-11 19:11:08 2024-05-11 19:11:08             5
# 283               NaN 2024-04-15 19:17:53 2024-10-12 19:17:15            10
# 301               NaN 2024-04-15 20:13:13 2024-05-15 20:13:13             5
#
#                                     City State
# 63                             McDonough    GA
# 69                                Dallas    TX
# 179                              Indiana    PA
# 283                               Austin    TX
# 301  Huntsville-Decatur-Albertville Area  None

# %%
specific_areas_abbrev={
    'United States': 'US',
    'Nebraska Metropolitan Area': 'NE',
    'Ohio Metropolitan Area': 'OH',
    'South Carolina Metropolitan Area': 'SC',
    'Texas Metropolitan Area': 'TX',
    'Oregon Metropolitan Area': 'OR',
    'Illinois Metropolitan Area': 'IL',
    'South Carolina Area': 'SC',
    'Massachusetts Metropolitan Area': 'MA',
    'Wisconsin Metropolitan Area': 'WI',
    'New York Metropolitan Area': 'NY',
    'North Carolina Metropolitan Area': 'NC',
    'Louisiana Metropolitan Area': 'LA',
    'Virginia Metropolitan Area': 'VA',
    'Georgia Area': 'GA',
    'South Holland': 'IL',
    'Indiana Metropolitan Area': 'IN',
    'Missouri Area': 'MO',
    'Illinois Area': 'IL',
    'North Carolina Area': 'NC',
    'IL Area': 'IL',
    'Maine Metropolitan Area': 'ME',
    'Minnesota Area': 'MN',
    'Kansas Metropolitan Area': 'KS',
    'NC Area': 'NC',
    'AR Area': 'AR',
    'AZ Area': 'AZ'
}

#We made another keyword dictionary for all of the regular entries to be remapped to the state abbreviation.
state_abbrev=state_abbreviations = {
    'New Jersey': 'NJ',
    'Colorado': 'CO',
    'Ohio': 'OH',
    'New York': 'NY',
    'Iowa': 'IA',
    'North Carolina': 'NC',
    'California': 'CA',
    'Nebraska': 'NE',
    'Florida': 'FL',
    'Michigan': 'MI',
    'Missouri': 'MO',
    'Tennessee': 'TN',
    'Alaska': 'AK',
    'Rhode Island': 'RI',
    'Alabama': 'AL',
    'Georgia': 'GA',
    'Texas': 'TX',
    'Pennsylvania': 'PA',
    'Massachusetts': 'MA',
    'Arizona': 'AZ',
    'Virginia': 'VA',
    'Washington': 'WA',
    'Wisconsin': 'WI',
    'Hawaii': 'HI',
    'Louisiana': 'LA',
    'Utah': 'UT',
    'Indiana': 'IN',
    'Minnesota': 'MN',
    'Maryland': 'MD',
    'Kentucky': 'KY',
    'Oregon': 'OR',
    'New Mexico': 'NM',
    'Illinois': 'IL',
    'Montana': 'MT',
    'Oklahoma': 'OK',
    'District of Columbia': 'DC',
    'Mississippi': 'MS',
    'South Carolina': 'SC',
    'Kansas': 'KS',
    'Arkansas': 'AR',
    'Connecticut': 'CT',
    'Nevada': 'NV',
    'Idaho': 'ID',
    'New Hampshire': 'NH',
    'Wyoming': 'WY',
    'South Dakota': 'SD',
    'North Dakota': 'ND',
    'Delaware': 'DE',
    'West Virginia': 'WV',
    'Vermont': 'VT',
    'Maine': 'ME'
}

#Replace specific locations and non-abbreviated states with an abbreviated state name. A number of postings did not
#specidy the city or state, instead it just said "United States". We assumed that these are remote jobs and thus put
#the state as US.
filtered_postings_df['State']=filtered_postings_df['State'].str.strip().replace(specific_areas_abbrev)
filtered_postings_df['State']=filtered_postings_df['State'].str.strip().replace(state_abbrev)

# %%
#Checking that the replacements were made correctly
filtered_postings_df['State'].unique()
# Out:
# array(['GA', 'TX', 'PA', None, 'MI', 'NY', 'US', 'CT', 'FL', 'IL', 'NJ',
#        'IA', 'VA', 'MA', 'CA', 'WA', 'CO', 'MD', 'NC', 'OK', 'WI', 'DE',
#        'UT', 'OH', 'AZ', 'IN', 'OR', 'MN', 'MO', 'AL', 'NE', 'HI', 'KY',
#        'KS', 'NM', 'TN', 'WV', 'ME', 'LA', 'DC', 'AR', 'SC', 'RI', 'AK',
#        'NH', 'MT', 'ND', 'MS', 'NV', 'WY', 'SD', 'ID', 'VT'], dtype=object)

# %% [markdown]
# **Analysing the data**

# %% [markdown]
# **Graph 1:Plotting the most posted skill level in the data industry.**
#
# The data shows that companies are mainly looking for Mid level experience from applicants

# %%
import plotly.express as px

experience_count = filtered_postings_df.groupby(['Experience']).size()
experience_count_df = experience_count.reset_index(name='count')
experience_count_df=experience_count_df.sort_values(by='count', ascending=True)
fig=px.bar(experience_count_df, x='Experience', y='count', color='Experience', title='Count of experience level required for jobs')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="7b6f0f6e-1b7f-477a-bc02-9ca520cc7a3d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7b6f0f6e-1b7f-477a-bc02-9ca520cc7a3d")) {                    Plotly.newPlot(                        "7b6f0f6e-1b7f-477a-bc02-9ca520cc7a3d",                        [{"alignmentgroup":"True","hovertemplate":"Experience=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Intern","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Intern","offsetgroup":"Intern","orientation":"v","showlegend":true,"textposition":"auto","x":["Intern"],"xaxis":"x","y":[1],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Experience=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Manager","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Manager","offsetgroup":"Manager","orientation":"v","showlegend":true,"textposition":"auto","x":["Manager"],"xaxis":"x","y":[3],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Experience=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Junior","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Junior","offsetgroup":"Junior","orientation":"v","showlegend":true,"textposition":"auto","x":["Junior"],"xaxis":"x","y":[62],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Experience=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Management","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Management","offsetgroup":"Management","orientation":"v","showlegend":true,"textposition":"auto","x":["Management"],"xaxis":"x","y":[183],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Experience=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Senior","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Senior","offsetgroup":"Senior","orientation":"v","showlegend":true,"textposition":"auto","x":["Senior"],"xaxis":"x","y":[1197],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Experience=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Mid","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Mid","offsetgroup":"Mid","orientation":"v","showlegend":true,"textposition":"auto","x":["Mid"],"xaxis":"x","y":[4152],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatma ...

# %% [markdown]
# **Graph 2:
# Plotting the experience level by state.**
#
# California and Texas are by far the biggest employers, with both states having the most postings for mid-level jobs, followed by senior jobs. Texas takes the lead with Junior positions and managerial positions. This follows recent trends of people, especially in tech, moving to Texas for the lower cost of living and better taxes.

# %%
experience_by_state = filtered_postings_df.groupby(['State', 'Experience']).size().reset_index(name='count')
fig = px.histogram(experience_by_state, x='count', y='State', color='Experience', title='Experience Levels by State')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="533ac281-48b6-4170-96ae-406d7aaac2c7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("533ac281-48b6-4170-96ae-406d7aaac2c7")) {                    Plotly.newPlot(                        "533ac281-48b6-4170-96ae-406d7aaac2c7",                        [{"alignmentgroup":"True","bingroup":"y","histfunc":"sum","hovertemplate":"Experience=Mid\u003cbr\u003esum of count=%{x}\u003cbr\u003eState=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Mid","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Mid","offsetgroup":"Mid","orientation":"h","showlegend":true,"x":[3,31,10,70,397,64,24,93,19,208,107,10,31,4,166,41,33,12,11,90,66,8,85,53,36,8,2,133,1,11,10,130,11,7,191,104,19,16,119,7,30,1,43,390,214,32,205,5,75,47,4,3],"xaxis":"x","y":["AK","AL","AR","AZ","CA","CO","CT","DC","DE","FL","GA","HI","IA","ID","IL","IN","KS","KY","LA","MA","MD","ME","MI","MN","MO","MS","MT","NC","ND","NE","NH","NJ","NM","NV","NY","OH","OK","OR","PA","RI","SC","SD","TN","TX","US","UT","VA","VT","WA","WI","WV","WY"],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"y","histfunc":"sum","hovertemplate":"Experience=Management\u003cbr\u003esum of count=%{x}\u003cbr\u003eState=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Management","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Management","offsetgroup":"Management","orientation":"h","showlegend":true,"x":[2,2,12,4,2,2,2,6,11,1,5,1,7,2,2,1,5,2,6,23,3,6,2,1,2,21,3,13,1,2,1],"xaxis":"x","y":["AL","AZ","CA","CO","CT","DC","DE","FL","GA","IA","IL","KS","MA","MD","MN","MS","NC","NE","NJ","NY","OH","PA","RI","SC","TN","TX","US","VA","VT","WA","WI"],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"y","histfunc":"sum","hovertemplate":"Experience=Senior\u003cbr\u003esum of count=%{x}\u003cbr\u003eState=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Senior","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Senior","offsetgroup":"Senior","orientation":"h","showlegend":true,"x":[3,5,19,113,19,20,19,2,62,39,3,2,2,59,8,8,3,2,33,17,2,20,25,9,2,29,1,6,5,48,5,71,29,1,7,22,2,8,11,107,43,7,59,24,12,1],"xaxis":"x","y":["AL","AR","AZ","CA","CO","CT","DC","DE","FL","GA","HI","IA","ID","IL","IN","KS","KY","LA","MA","MD","ME","MI","MN","MO","MS","NC","ND","NE","NH","NJ","NV","NY","OH","OK","OR","PA","RI","SC","TN","TX","US","UT","VA","WA","WI","WV"],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"y","histfunc":"sum","hovertemplate":"Experience=Junior\u003cbr\u003esum of count=%{x}\u003cbr\u003eState=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Junior","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Junior","offsetgroup":"Junior","orientation":"h","showlegend":true,"x":[1,2,2,2,1,2,5,2,2,2,1,1,1,1,1,3,1,7,1,1,9,1,1],"xaxis":"x","y":["AZ","CA","CO","DC","DE","FL","GA","IL","MA","MD","MI","NC","NJ","NY","OH","PA","TN","TX","US","UT","VA","WA","WV"],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"y","histfunc":"sum","hovertemplate":"Experience=Intern\u003cbr\u003esum of count=%{x}\u003cbr\u003eState=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Intern","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Intern","offsetgroup":"Intern","orientation":"h","showlegend":true,"x":[1],"xaxis":"x","y":["TN"],"yaxis":"y","type":"histogram"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.55555555555555 ...

# %% [markdown]
# **Graph 3: Plotting the most poular job titles**
#
# By using a filtered dataFrame looking at job titles that inclide the word Analyst. We found that the most posted jobs on LinkedIn are Business Analyst and Data Analst.

# %%
grouped_jobs = filtered_postings_df.groupby(['title']).size().reset_index(name='count')
grouped_jobs=grouped_jobs.nlargest(15,'count').sort_values(by='count', ascending=True)
fig=px.bar(grouped_jobs, x='title', y='count', color='title', title='Most popular jobs', labels={'count':'Number of jobs', 'title':'Job title'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="47fd5edf-c27a-407f-966f-018ba8397097" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("47fd5edf-c27a-407f-966f-018ba8397097")) {                    Plotly.newPlot(                        "47fd5edf-c27a-407f-966f-018ba8397097",                        [{"alignmentgroup":"True","hovertemplate":"Job title=%{x}\u003cbr\u003eNumber of jobs=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Compliance Analyst","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Compliance Analyst","offsetgroup":"Compliance Analyst","orientation":"v","showlegend":true,"textposition":"auto","x":["Compliance Analyst"],"xaxis":"x","y":[20],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Job title=%{x}\u003cbr\u003eNumber of jobs=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Online Data Analyst","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Online Data Analyst","offsetgroup":"Online Data Analyst","orientation":"v","showlegend":true,"textposition":"auto","x":["Online Data Analyst"],"xaxis":"x","y":[20],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Job title=%{x}\u003cbr\u003eNumber of jobs=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Supply Chain Analyst","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Supply Chain Analyst","offsetgroup":"Supply Chain Analyst","orientation":"v","showlegend":true,"textposition":"auto","x":["Supply Chain Analyst"],"xaxis":"x","y":[20],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Job title=%{x}\u003cbr\u003eNumber of jobs=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Senior Data Scientist","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Senior Data Scientist","offsetgroup":"Senior Data Scientist","orientation":"v","showlegend":true,"textposition":"auto","x":["Senior Data Scientist"],"xaxis":"x","y":[21],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Job title=%{x}\u003cbr\u003eNumber of jobs=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Board Certified Behavior Analyst","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Board Certified Behavior Analyst","offsetgroup":"Board Certified Behavior Analyst","orientation":"v","showlegend":true,"textposition":"auto","x":["Board Certified Behavior Analyst"],"xaxis":"x","y":[24],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Job title=%{x}\u003cbr\u003eNumber of jobs=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Senior Data Analyst","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Senior Data Analyst","offsetgroup":"Senior Data Analyst","orientation":"v","showlegend":true,"textposition":"auto","x":["Senior Data Analyst"],"xaxis":"x","y":[25],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Job title=%{x}\u003cbr\u003eNumber of jobs=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Senior Business Analyst","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Senior Business Analyst","offsetgroup":"Senior Business Analyst","orientation":"v","showlegend":true,"textposition":"auto","x":["Senior Business Analyst"],"xaxis":"x","y":[34],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Job title=%{x}\u003cbr\u003eNumber of jobs=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Senior Data Engineer","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Senior Data Engineer","offsetgroup":"Senior Data Engineer","orientation":"v","showlegend":true,"textposition":"auto","x":["Senior Data Engineer"],"xaxis":"x","y":[44],"yaxis":"y","type":"bar"},{"alignmentgroup":"T ...

# %% [markdown]
# **Graph 4: Plotting the top 10 employers**
#
# We found that The Job Network, Cogent Communications, and Dice are the companies that posted the most amount jobs on LinkedIn. The Job Network and Dice are both career marketplaces.

# %%
employers = filtered_postings_df.groupby(['company_name']).size().reset_index(name='count')
employers_top_10=employers.nlargest(15, 'count')
employers_top_10=employers_top_10.sort_values(by='count', ascending=True)
fig=px.bar(employers_top_10, x='company_name', y='count', color='company_name', title='Top 10 employers')
fig.update_yaxes(title_text='No. of posts')
fig.update_layout(showlegend=False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="a1107c67-c15f-43fe-8012-6afa4d448f02" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a1107c67-c15f-43fe-8012-6afa4d448f02")) {                    Plotly.newPlot(                        "a1107c67-c15f-43fe-8012-6afa4d448f02",                        [{"alignmentgroup":"True","hovertemplate":"company_name=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Akkodis","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Akkodis","offsetgroup":"Akkodis","orientation":"v","showlegend":true,"textposition":"auto","x":["Akkodis"],"xaxis":"x","y":[23],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"company_name=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Fidelity Investments","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Fidelity Investments","offsetgroup":"Fidelity Investments","orientation":"v","showlegend":true,"textposition":"auto","x":["Fidelity Investments"],"xaxis":"x","y":[23],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"company_name=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"ICE","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"ICE","offsetgroup":"ICE","orientation":"v","showlegend":true,"textposition":"auto","x":["ICE"],"xaxis":"x","y":[24],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"company_name=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"ClearanceJobs","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"ClearanceJobs","offsetgroup":"ClearanceJobs","orientation":"v","showlegend":true,"textposition":"auto","x":["ClearanceJobs"],"xaxis":"x","y":[26],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"company_name=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Citi","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Citi","offsetgroup":"Citi","orientation":"v","showlegend":true,"textposition":"auto","x":["Citi"],"xaxis":"x","y":[27],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"company_name=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"TEKsystems","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"TEKsystems","offsetgroup":"TEKsystems","orientation":"v","showlegend":true,"textposition":"auto","x":["TEKsystems"],"xaxis":"x","y":[35],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"company_name=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Capital One","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Capital One","offsetgroup":"Capital One","orientation":"v","showlegend":true,"textposition":"auto","x":["Capital One"],"xaxis":"x","y":[37],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"company_name=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"DataAnnotation","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"DataAnnotation","offsetgroup":"DataAnnotation","orientation":"v","showlegend":true,"textposition":"auto","x":["DataAnnotation"],"xaxis":"x","y":[38],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"company_name=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"USAA","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"USAA","offsetgroup":"USAA","orientation":"v","showlegend":true,"textposition":"auto","x":["USAA"],"xaxis":"x","y":[38],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"company_name=%{x}\u003cbr\u003ecoun ...

# %% [markdown]
# **Graph 5: Plotting Top 15 Description words**
#
# We found the words Analyst, Data, Senior, and Business are included the most times in LinkedIn job postings

# %%
from collections import Counter
import re

def remove_special_characters(text):
    return re.sub(r'[^A-Za-z\s]', '', text)

filtered_postings_df['cleaned_title'] = filtered_postings_df['title'].apply(remove_special_characters)
all_text = ' '.join(filtered_postings_df['cleaned_title'])
word_counts = Counter(all_text.split())

top_words = pd.DataFrame(word_counts.most_common(15), columns=['word','count'])
print(top_words)

fig = px.pie(top_words, values='count', names='word')
fig.show()
# Out:
#           word  count
# 0      Analyst   4736
# 1         Data   1181
# 2       Senior    879
# 3     Business    789
# 4    Financial    491
# 5     Engineer    362
# 6           Sr    289
# 7    Scientist    234
# 8   Operations    199
# 9          and    185
# 10     Systems    174
# 11    Security    172
# 12          II    157
# 13     Support    150
# 14      Remote    143
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="aaf454e9-7bf6-47c2-9941-20b0cf23c0d7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("aaf454e9-7bf6-47c2-9941-20b0cf23c0d7")) {                    Plotly.newPlot(                        "aaf454e9-7bf6-47c2-9941-20b0cf23c0d7",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"word=%{label}\u003cbr\u003ecount=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Analyst","Data","Senior","Business","Financial","Engineer","Sr","Scientist","Operations","and","Systems","Security","II","Support","Remote"],"legendgroup":"","name":"","showlegend":true,"values":[4736,1181,879,789,491,362,289,234,199,185,174,172,157,150,143],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scatterge ...

# %%
file = '/content/drive/MyDrive/Hackathon/jobs/job_skills.csv'
skills_df = pd.read_csv(file)
skills_df.head(5)
# Out:
#        job_id skill_abr
# 0  3884428798      MRKT
# 1  3884428798        PR
# 2  3884428798       WRT
# 3  3887473071      SALE
# 4  3887465684       FIN

# %%
skill_count = skills_df.groupby(['skill_abr']).size()

# %% [markdown]
# **Graph 6: Plotting Job Skills over Number of Postings**
#
# For the following graphs, we looked at data from all of the job postings and not only jobs relating to data or analytics.
#
# We found the most wanted skills for jobs on LinkedIn were IT, Sales, and Management.

# %%
import plotly.express as px

skill_count_df = skill_count.reset_index(name='count')
skill_count_df=skill_count_df.sort_values(by='count', ascending=True)
fig = px.bar(skill_count_df, x='skill_abr', y='count',color='skill_abr', title='Skills v Job Count', text='count', labels={'skill_abr': 'Skills', 'count': 'Number of Jobs per Skill'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="ee099994-9fe9-4604-a663-6d253ba6d5f3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ee099994-9fe9-4604-a663-6d253ba6d5f3")) {                    Plotly.newPlot(                        "ee099994-9fe9-4604-a663-6d253ba6d5f3",                        [{"alignmentgroup":"True","hovertemplate":"Skills=%{x}\u003cbr\u003eNumber of Jobs per Skill=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"DIST","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"DIST","offsetgroup":"DIST","orientation":"v","showlegend":true,"text":[416.0],"textposition":"auto","x":["DIST"],"xaxis":"x","y":[416],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Skills=%{x}\u003cbr\u003eNumber of Jobs per Skill=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"PRCH","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"PRCH","offsetgroup":"PRCH","orientation":"v","showlegend":true,"text":[610.0],"textposition":"auto","x":["PRCH"],"xaxis":"x","y":[610],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Skills=%{x}\u003cbr\u003eNumber of Jobs per Skill=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"ADVR","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"ADVR","offsetgroup":"ADVR","orientation":"v","showlegend":true,"text":[681.0],"textposition":"auto","x":["ADVR"],"xaxis":"x","y":[681],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Skills=%{x}\u003cbr\u003eNumber of Jobs per Skill=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"PROD","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"PROD","offsetgroup":"PROD","orientation":"v","showlegend":true,"text":[762.0],"textposition":"auto","x":["PROD"],"xaxis":"x","y":[762],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Skills=%{x}\u003cbr\u003eNumber of Jobs per Skill=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"SCI","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"SCI","offsetgroup":"SCI","orientation":"v","showlegend":true,"text":[813.0],"textposition":"auto","x":["SCI"],"xaxis":"x","y":[813],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Skills=%{x}\u003cbr\u003eNumber of Jobs per Skill=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"STRA","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"STRA","offsetgroup":"STRA","orientation":"v","showlegend":true,"text":[1178.0],"textposition":"auto","x":["STRA"],"xaxis":"x","y":[1178],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Skills=%{x}\u003cbr\u003eNumber of Jobs per Skill=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"SUPL","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"SUPL","offsetgroup":"SUPL","orientation":"v","showlegend":true,"text":[1180.0],"textposition":"auto","x":["SUPL"],"xaxis":"x","y":[1180],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Skills=%{x}\u003cbr\u003eNumber of Jobs per Skill=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"PR","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"PR","offsetgroup":"PR","orientation":"v","showlegend":true,"text":[1298.0],"textposition":"auto","x":["PR"],"xaxis":"x","y":[1298],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Skills=%{x}\u003cbr\u003eNumber of Jobs per Skill=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"PRDM","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"PRDM","offsetgroup":"PRDM","orientation":"v","showlegend":true,"text":[1362.0],"textposition":"auto","x":["PRDM"],"xaxis":"x","y":[1362],"yaxis":"y","type": ...

# %%
file = ('/content/drive/MyDrive/Hackathon/jobs/benefits.csv')
benefits_df = pd.read_csv(file)
benefits_df.head(5)
# Out:
#        job_id  inferred                     type
# 0  3887473071         0        Medical insurance
# 1  3887473071         0         Vision insurance
# 2  3887473071         0         Dental insurance
# 3  3887473071         0                   401(k)
# 4  3887473071         0  Student loan assistance

# %%
ji_file = ('/content/drive/MyDrive/Hackathon/jobs/job_industries.csv')
in_file = ('/content/drive/MyDrive/Hackathon/mappings/industries.csv')
ji_df = pd.read_csv(ji_file)
in_df = pd.read_csv(in_file)

# %%
merged_df1 = pd.merge(ji_df, in_df, on='industry_id')

final_merged_df = pd.merge(merged_df1, skills_df, on='job_id')

final_merged_df.head(5)
# Out:
#        job_id  industry_id                   industry_name skill_abr
# 0  3884428798           82  Book and Periodical Publishing      MRKT
# 1  3884428798           82  Book and Periodical Publishing        PR
# 2  3884428798           82  Book and Periodical Publishing       WRT
# 3  3887467939           82  Book and Periodical Publishing      SALE
# 4  3887467939           82  Book and Periodical Publishing      ADVR

# %% [markdown]
# **Graph 7: Plotting the Number of Skills per Industry**
#
# We merged two dataFrames - one including Skills per job posting and the other including Industries of each Company that is posting jobs. Again, this is looking at all the jobs data, so it is unsurprising that the healthcare industry is such a dominant employer in the USA with retail coming in a close second.

# %%
skills_industry = final_merged_df.groupby(['industry_name', 'skill_abr']).size().reset_index(name='count')
filtered_skills_industry = skills_industry[skills_industry['count'] >= 600]
filtered_skills_industry=filtered_skills_industry.sort_values(by='count', ascending=True)
fig = px.histogram(filtered_skills_industry, x='count', y='industry_name', color='skill_abr', title='Skills per Industry')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="0d38bcfd-8d10-49dc-a57e-f4fc033deb1e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0d38bcfd-8d10-49dc-a57e-f4fc033deb1e")) {                    Plotly.newPlot(                        "0d38bcfd-8d10-49dc-a57e-f4fc033deb1e",                        [{"alignmentgroup":"True","bingroup":"y","histfunc":"sum","hovertemplate":"skill_abr=BD\u003cbr\u003esum of count=%{x}\u003cbr\u003eindustry_name=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"BD","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"BD","offsetgroup":"BD","orientation":"h","showlegend":true,"x":[602,653,654,714,949,1865,3408],"xaxis":"x","y":["Insurance","Retail Apparel and Fashion","Software Development","Telecommunications","IT Services and IT Consulting","Financial Services","Retail"],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"y","histfunc":"sum","hovertemplate":"skill_abr=OTHR\u003cbr\u003esum of count=%{x}\u003cbr\u003eindustry_name=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"OTHR","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"OTHR","offsetgroup":"OTHR","orientation":"h","showlegend":true,"x":[611,651,696,1542,2063],"xaxis":"x","y":["Financial Services","Non-profit Organizations","IT Services and IT Consulting","Retail","Hospitals and Health Care"],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"y","histfunc":"sum","hovertemplate":"skill_abr=IT\u003cbr\u003esum of count=%{x}\u003cbr\u003eindustry_name=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"IT","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"IT","offsetgroup":"IT","orientation":"h","showlegend":true,"x":[611,677,708,736,908,1458,1664,1910,2294,5967],"xaxis":"x","y":["Construction","Retail","Banking","Defense and Space Manufacturing","Information Services","Hospitals and Health Care","Staffing and Recruiting","Financial Services","Software Development","IT Services and IT Consulting"],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"y","histfunc":"sum","hovertemplate":"skill_abr=EDU\u003cbr\u003esum of count=%{x}\u003cbr\u003eindustry_name=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"EDU","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"EDU","offsetgroup":"EDU","orientation":"h","showlegend":true,"x":[616],"xaxis":"x","y":["Education Administration Programs"],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"y","histfunc":"sum","hovertemplate":"skill_abr=ENG\u003cbr\u003esum of count=%{x}\u003cbr\u003eindustry_name=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"ENG","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"ENG","offsetgroup":"ENG","orientation":"h","showlegend":true,"x":[626,661,717,779,1512,2319],"xaxis":"x","y":["Engineering Services","Civil Engineering","Staffing and Recruiting","Financial Services","Software Development","IT Services and IT Consulting"],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"y","histfunc":"sum","hovertemplate":"skill_abr=GENB\u003cbr\u003esum of count=%{x}\u003cbr\u003eindustry_name=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"GENB","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"GENB","offsetgroup":"GENB","orientation":"h","showlegend":true,"x":[633],"xaxis":"x","y":["Retail"],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"y","histfunc":"sum","hovertemplate":"skill_abr=MNFC\u003cbr\u003esum of count=%{x}\u003cbr\u003eindustry_name=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"MNFC","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"MNFC","offsetgroup":"M ...

# %% [markdown]
# **Graph 8: Comparing the most popular types of job benefits**
#
# We found the most given benefits from companies were 401(k), Medical Insurance, and Vision Insurance.

# %%
import plotly.express as px

benefit_count = benefits_df.groupby(['type']).size()
benefit_count_df = benefit_count.reset_index(name='count')
benefit_count_df=benefit_count_df.sort_values(by='count', ascending=True)
fig = px.bar(benefit_count_df, x='type', y='count',color='type', title='Benefit v Job Count', text='count',
                  labels= {"type": "Type of Benefit", "count": "Number of jobs with Benefit"})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="a6564367-4bbf-4113-a4cd-07995595b76b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a6564367-4bbf-4113-a4cd-07995595b76b")) {                    Plotly.newPlot(                        "a6564367-4bbf-4113-a4cd-07995595b76b",                        [{"alignmentgroup":"True","hovertemplate":"Type of Benefit=%{x}\u003cbr\u003eNumber of jobs with Benefit=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Child care support","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Child care support","offsetgroup":"Child care support","orientation":"v","showlegend":true,"text":[273.0],"textposition":"auto","x":["Child care support"],"xaxis":"x","y":[273],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Type of Benefit=%{x}\u003cbr\u003eNumber of jobs with Benefit=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Student loan assistance","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Student loan assistance","offsetgroup":"Student loan assistance","orientation":"v","showlegend":true,"text":[365.0],"textposition":"auto","x":["Student loan assistance"],"xaxis":"x","y":[365],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Type of Benefit=%{x}\u003cbr\u003eNumber of jobs with Benefit=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Pension plan","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Pension plan","offsetgroup":"Pension plan","orientation":"v","showlegend":true,"text":[906.0],"textposition":"auto","x":["Pension plan"],"xaxis":"x","y":[906],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Type of Benefit=%{x}\u003cbr\u003eNumber of jobs with Benefit=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Paid paternity leave","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Paid paternity leave","offsetgroup":"Paid paternity leave","orientation":"v","showlegend":true,"text":[1540.0],"textposition":"auto","x":["Paid paternity leave"],"xaxis":"x","y":[1540],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Type of Benefit=%{x}\u003cbr\u003eNumber of jobs with Benefit=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Paid maternity leave","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Paid maternity leave","offsetgroup":"Paid maternity leave","orientation":"v","showlegend":true,"text":[1808.0],"textposition":"auto","x":["Paid maternity leave"],"xaxis":"x","y":[1808],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Type of Benefit=%{x}\u003cbr\u003eNumber of jobs with Benefit=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Commuter benefits","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Commuter benefits","offsetgroup":"Commuter benefits","orientation":"v","showlegend":true,"text":[2226.0],"textposition":"auto","x":["Commuter benefits"],"xaxis":"x","y":[2226],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Type of Benefit=%{x}\u003cbr\u003eNumber of jobs with Benefit=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Tuition assistance","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Tuition assistance","offsetgroup":"Tuition assistance","orientation":"v","showlegend":true,"text":[2614.0],"textposition":"auto","x":["Tuition assistance"],"xaxis":"x","y":[2614],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Type of Benefit=%{x}\u003cbr\u003eNumber of jobs with Benefit=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Dental insurance","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Dental insurance" ...
